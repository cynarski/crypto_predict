# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Ustawienia wyświetlania wykresów
# %matplotlib inline

# Pobranie danych od 01-01-2019 do 31-12-2022
df = yf.download('ETH-USD', start='2019-01-01', end='2021-12-31')

# Użyjemy tylko kolumny 'Close' jako cechy
data = df[['Close']].values

# Skalowanie danych do zakresu (0,1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Definiowanie funkcji do tworzenia sekwencji danych
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        X.append(dataset[i-look_back:i, 0])
        Y.append(dataset[i, 0])
    return np.array(X), np.array(Y)

# Tworzenie sekwencji z look_back = 60 dni
look_back = 60
X, Y = create_dataset(scaled_data, look_back)

# Reshape danych wejściowych do formatu [próbki, timesteps, cechy]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Podział na zbiór treningowy i testowy (80% treningowy, 20% walidacyjny)
train_size = int(len(X) * 0.7)
X_train, X_val = X[:train_size], X[train_size:]
Y_train, Y_val = Y[:train_size], Y[train_size:]

# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(units=256, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.3))
model.add(LSTM(units=128, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(64))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
model.compile(loss='mean_squared_error', optimizer='adam')

# Trenowanie modelu z walidacją
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_val, Y_val), verbose=1)

# Predykcja na zbiorze walidacyjnym
predicted_val = model.predict(X_val)
predicted_val = scaler.inverse_transform(predicted_val)
Y_val_inverse = scaler.inverse_transform(Y_val.reshape(-1, 1))

# Pobranie dat dla zbioru walidacyjnego
validation_dates = df.index[look_back + train_size:]

# Wykres porównujący na zbiorze walidacyjnym
plt.figure(figsize=(14,5))
plt.plot(validation_dates, Y_val_inverse, color='black', label='Rzeczywiste ceny AAPL (walidacja)')
plt.plot(validation_dates, predicted_val, color='green', label='Przewidywane ceny AAPL (walidacja)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL na zbiorze walidacyjnym')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Michał\Desktop\crypto\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 60, 256)        │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 60, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 512,371 (1.95 MB)
#  Trainable params: 512,371 (1.95 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0043 - val_loss: 0.0127
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 6.3201e-04 - val_loss: 0.0076
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 2.0296e-04 - val_loss: 0.0233
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 2.2977e-04 - val_loss: 0.0075
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.1939e-04 - val_loss: 0.0060
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.4248e-04 - val_loss: 0.0091
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.4351e-04 - val_loss: 0.0093
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.2489e-04 - val_loss: 0.0083
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.5570e-04 - val_loss: 0.0053
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.3575e-04 - val_loss: 0.0062
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 1.3277e-04 - val_loss: 0.0117
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.5833e-04 - val_loss: 0.0050
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.5248e-04 - val_loss: 0.0085
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 1.5875e-04 - val_loss: 0.0117
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 1.6372e-04 - val_loss: 0.0064
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 1.4496e-04 - val_loss: 0.0046
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 1.2677e-04 - val_loss: 0.0087
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 1.0848e-04 - val_loss: 0.0082
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 1.4912e-04 - val_loss: 0.0076
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 1.3239e-04 - val_loss: 0.0121
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.8423e-04 - val_loss: 0.0074
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.2101e-04 - val_loss: 0.0042
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.0893e-04 - val_loss: 0.0045
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 1.6476e-04 - val_loss: 0.0060
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.3333e-04 - val_loss: 0.0040
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 1.5574e-04 - val_loss: 0.0055
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 1.0036e-04 - val_loss: 0.0037
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 1.1576e-04 - val_loss: 0.0037
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - loss: 1.2175e-04 - val_loss: 0.0036
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 1.2893e-04 - val_loss: 0.0063
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.3268e-04 - val_loss: 0.0066
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 1.2849e-04 - val_loss: 0.0050
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 9.7400e-05 - val_loss: 0.0038
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.1360e-04 - val_loss: 0.0042
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 8.9767e-05 - val_loss: 0.0037
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 9.2566e-05 - val_loss: 0.0034
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 9.8254e-05 - val_loss: 0.0034
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 1.3939e-04 - val_loss: 0.0033
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.1124e-04 - val_loss: 0.0033
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 1.1882e-04 - val_loss: 0.0033
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 7.7123e-05 - val_loss: 0.0031
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 1.3402e-04 - val_loss: 0.0037
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.1336e-04 - val_loss: 0.0037
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.6014e-04 - val_loss: 0.0032
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.1334e-04 - val_loss: 0.0031
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 1.3523e-04 - val_loss: 0.0030
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 1.6218e-04 - val_loss: 0.0051
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 1.1463e-04 - val_loss: 0.0045
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 1.0908e-04 - val_loss: 0.0030
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 8.7000e-05 - val_loss: 0.0031
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 9.2581e-05 - val_loss: 0.0034
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 7.8937e-05 - val_loss: 0.0029
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.0799e-04 - val_loss: 0.0033
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.2053e-04 - val_loss: 0.0044
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.1920e-04 - val_loss: 0.0053
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.3741e-04 - val_loss: 0.0030
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.2222e-04 - val_loss: 0.0040
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.1158e-04 - val_loss: 0.0037
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.1031e-04 - val_loss: 0.0027
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.0524e-04 - val_loss: 0.0045
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.2550e-04 - val_loss: 0.0030
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 9.3423e-05 - val_loss: 0.0027
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 7.5129e-05 - val_loss: 0.0027
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 1.8232e-04 - val_loss: 0.0060
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 1.2685e-04 - val_loss: 0.0033
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 1.1749e-04 - val_loss: 0.0034
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 7.8959e-05 - val_loss: 0.0029
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 8.6704e-05 - val_loss: 0.0030
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 8.6394e-05 - val_loss: 0.0029
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 1.0584e-04 - val_loss: 0.0041
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 9.3660e-05 - val_loss: 0.0031
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 9.1198e-05 - val_loss: 0.0049
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 1.2481e-04 - val_loss: 0.0047
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 1.0738e-04 - val_loss: 0.0036
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 9.0024e-05 - val_loss: 0.0036
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 8.3816e-05 - val_loss: 0.0027
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 9.2025e-05 - val_loss: 0.0026
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 8.0458e-05 - val_loss: 0.0033
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.1950e-04 - val_loss: 0.0048
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.2677e-04 - val_loss: 0.0028
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 8.6470e-05 - val_loss: 0.0035
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 9.1108e-05 - val_loss: 0.0026
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 9.2925e-05 - val_loss: 0.0029
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.1911e-04 - val_loss: 0.0026
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 6.6808e-05 - val_loss: 0.0039
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.0644e-04 - val_loss: 0.0032
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 8.3167e-05 - val_loss: 0.0078
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.5102e-04 - val_loss: 0.0028
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 7.7743e-05 - val_loss: 0.0025
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 6.2978e-05 - val_loss: 0.0031
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 9.0965e-05 - val_loss: 0.0045
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 8.4701e-05 - val_loss: 0.0037
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 8.4096e-05 - val_loss: 0.0029
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 7.5222e-05 - val_loss: 0.0030
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.0904e-04 - val_loss: 0.0023
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 7.0803e-05 - val_loss: 0.0023
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 7.2594e-05 - val_loss: 0.0022
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 9.0016e-05 - val_loss: 0.0022
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 5.9955e-05 - val_loss: 0.0022
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 5.6122e-05 - val_loss: 0.0021
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step

# %%
# Pobranie danych do 31-12-2022 dla predykcji na styczeń 2023
train_data = yf.download('ETH-USD', start='2019-01-01', end='2021-12-31')
train_close = train_data[['Close']].values

# Pobranie danych od 01-01-2023 do 31-01-2023 (bez patrzenia na nie)
test_data = yf.download('ETH-USD', start='2022-01-01', end='2022-04-30')
actual_prices = test_data[['Close']].values

# Łączenie danych w celu zachowania ciągłości sekwencji
total_dataset = np.concatenate((train_close, actual_prices), axis=0)

# Przygotowanie danych do predykcji
inputs = total_dataset[len(total_dataset) - len(actual_prices) - look_back:]
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(look_back, len(inputs)):
    X_test.append(inputs[i-look_back:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Predykcja cen na styczeń 2023
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# Rzeczywiste ceny zamknięcia dla stycznia 2023
real_prices = test_data['Close'].values

# Daty dla stycznia 2023
test_dates = test_data.index

# Wykres porównujący dla stycznia 2023
plt.figure(figsize=(14,5))
plt.plot(test_dates, real_prices, color='red', label='Rzeczywiste ceny AAPL (styczeń 2023)')
plt.plot(test_dates, predicted_prices, color='green', label='Przewidywane ceny AAPL (styczeń 2023)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL w styczniu 2023')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
