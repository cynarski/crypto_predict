# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Ustawienia wyświetlania wykresów
# %matplotlib inline

# Pobranie danych od 01-01-2019 do 31-12-2022
df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')

# Użyjemy tylko kolumny 'Close' jako cechy
data = df[['Close']].values

# Skalowanie danych do zakresu (0,1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Definiowanie funkcji do tworzenia sekwencji danych
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        X.append(dataset[i-look_back:i, 0])
        Y.append(dataset[i, 0])
    return np.array(X), np.array(Y)

# Tworzenie sekwencji z look_back = 60 dni
look_back = 60
X, Y = create_dataset(scaled_data, look_back)

# Reshape danych wejściowych do formatu [próbki, timesteps, cechy]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Podział na zbiór treningowy i testowy (80% treningowy, 20% walidacyjny)
train_size = int(len(X) * 0.7)
X_train, X_val = X[:train_size], X[train_size:]
Y_train, Y_val = Y[:train_size], Y[train_size:]

# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.3))
model.add(LSTM(units=64))
model.add(Dropout(0.3))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
model.compile(loss='mean_squared_error', optimizer='adam')

# Trenowanie modelu z walidacją
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_data=(X_val, Y_val), verbose=1)

# Predykcja na zbiorze walidacyjnym
predicted_val = model.predict(X_val)
predicted_val = scaler.inverse_transform(predicted_val)
Y_val_inverse = scaler.inverse_transform(Y_val.reshape(-1, 1))

# Pobranie dat dla zbioru walidacyjnego
validation_dates = df.index[look_back + train_size:]

# Wykres porównujący na zbiorze walidacyjnym
plt.figure(figsize=(14,5))
plt.plot(validation_dates, Y_val_inverse, color='black', label='Rzeczywiste ceny AAPL (walidacja)')
plt.plot(validation_dates, predicted_val, color='green', label='Przewidywane ceny AAPL (walidacja)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL na zbiorze walidacyjnym')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()

# Pobranie danych do 31-12-2022 dla predykcji na styczeń 2023
train_data = yf.download('AAPL', start='2019-01-01', end='2023-12-31')
train_close = train_data[['Close']].values

# Pobranie danych od 01-01-2023 do 31-01-2023 (bez patrzenia na nie)
test_data = yf.download('AAPL', start='2024-01-01', end='2024-03-31')
actual_prices = test_data[['Close']].values

# Łączenie danych w celu zachowania ciągłości sekwencji
total_dataset = np.concatenate((train_close, actual_prices), axis=0)

# Przygotowanie danych do predykcji
inputs = total_dataset[len(total_dataset) - len(actual_prices) - look_back:]
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(look_back, len(inputs)):
    X_test.append(inputs[i-look_back:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Predykcja cen na styczeń 2023
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# Rzeczywiste ceny zamknięcia dla stycznia 2023
real_prices = test_data['Close'].values

# Daty dla stycznia 2023
test_dates = test_data.index

# Wykres porównujący dla stycznia 2023
plt.figure(figsize=(14,5))
plt.plot(test_dates, real_prices, color='red', label='Rzeczywiste ceny AAPL (styczeń 2023)')
plt.plot(test_dates, predicted_prices, color='green', label='Przewidywane ceny AAPL (styczeń 2023)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL w styczniu 2023')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Michał\Desktop\crypto\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 117,619 (459.45 KB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0137 - val_loss: 0.0012
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 8.6768e-04 - val_loss: 0.0023
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 7.1262e-04 - val_loss: 0.0014
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 6.4496e-04 - val_loss: 0.0013
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 9.4856e-04 - val_loss: 9.6147e-04
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 7.6111e-04 - val_loss: 8.6646e-04
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 7.8802e-04 - val_loss: 9.3359e-04
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.2278e-04 - val_loss: 0.0018
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.4356e-04 - val_loss: 0.0028
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.3412e-04 - val_loss: 0.0031
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.3890e-04 - val_loss: 7.9280e-04
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.7758e-04 - val_loss: 0.0034
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.8704e-04 - val_loss: 0.0015
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.0879e-04 - val_loss: 0.0034
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.2380e-04 - val_loss: 0.0015
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.7826e-04 - val_loss: 0.0049
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.6567e-04 - val_loss: 7.7935e-04
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.3641e-04 - val_loss: 6.6319e-04
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.0607e-04 - val_loss: 9.3256e-04
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.2639e-04 - val_loss: 6.4228e-04
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.3355e-04 - val_loss: 9.5268e-04
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.5777e-04 - val_loss: 7.7686e-04
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.0667e-04 - val_loss: 0.0025
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.0516e-04 - val_loss: 9.3324e-04
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.3015e-04 - val_loss: 6.0789e-04
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.1161e-04 - val_loss: 0.0016
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.1875e-04 - val_loss: 7.3447e-04
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8923e-04 - val_loss: 0.0031
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.6293e-04 - val_loss: 0.0014
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.8299e-04 - val_loss: 5.8503e-04
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.3731e-04 - val_loss: 7.6104e-04
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.9221e-04 - val_loss: 0.0022
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 5.6693e-04 - val_loss: 0.0044
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5916e-04 - val_loss: 0.0020
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.2581e-04 - val_loss: 0.0016
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.8406e-04 - val_loss: 0.0043
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.4102e-04 - val_loss: 9.7988e-04
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.4402e-04 - val_loss: 0.0012
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5275e-04 - val_loss: 0.0010
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.6660e-04 - val_loss: 5.4957e-04
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.1564e-04 - val_loss: 0.0025
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.2072e-04 - val_loss: 0.0019
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.8746e-04 - val_loss: 0.0011
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.3213e-04 - val_loss: 0.0017
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8265e-04 - val_loss: 6.6512e-04
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.8882e-04 - val_loss: 0.0020
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.2811e-04 - val_loss: 5.1412e-04
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.9068e-04 - val_loss: 6.1313e-04
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.4221e-04 - val_loss: 8.5031e-04
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5872e-04 - val_loss: 4.5437e-04
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.0763e-04 - val_loss: 6.7301e-04
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8002e-04 - val_loss: 4.6192e-04
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.4928e-04 - val_loss: 4.6093e-04
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.9405e-04 - val_loss: 0.0041
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.9832e-04 - val_loss: 0.0012
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5666e-04 - val_loss: 0.0047
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5331e-04 - val_loss: 9.5469e-04
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.2404e-04 - val_loss: 9.2787e-04
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5496e-04 - val_loss: 0.0010
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.4571e-04 - val_loss: 5.6650e-04
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.8430e-04 - val_loss: 5.4868e-04
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.7406e-04 - val_loss: 5.7823e-04
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.4389e-04 - val_loss: 0.0020
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.2868e-04 - val_loss: 9.1743e-04
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.1787e-04 - val_loss: 8.0700e-04
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0165e-04 - val_loss: 4.4073e-04
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5419e-04 - val_loss: 9.2881e-04
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.6115e-04 - val_loss: 6.4118e-04
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.5990e-04 - val_loss: 4.3672e-04
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.2418e-04 - val_loss: 8.4518e-04
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.3892e-04 - val_loss: 4.0758e-04
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.6897e-04 - val_loss: 0.0022
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3628e-04 - val_loss: 0.0017
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.8652e-04 - val_loss: 6.1925e-04
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.6191e-04 - val_loss: 6.9051e-04
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0307e-04 - val_loss: 4.2548e-04
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.0788e-04 - val_loss: 0.0013
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.6580e-04 - val_loss: 4.1610e-04
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.1894e-04 - val_loss: 5.8689e-04
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.3906e-04 - val_loss: 0.0017
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3496e-04 - val_loss: 4.4125e-04
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5704e-04 - val_loss: 4.2178e-04
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.8636e-04 - val_loss: 4.6665e-04
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7082e-04 - val_loss: 8.5974e-04
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.9492e-04 - val_loss: 4.4134e-04
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.4722e-04 - val_loss: 4.0150e-04
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5914e-04 - val_loss: 0.0014
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5151e-04 - val_loss: 3.8644e-04
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.3848e-04 - val_loss: 4.0920e-04
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.5168e-04 - val_loss: 0.0027
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.2839e-04 - val_loss: 0.0019
# Epoch 93/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.9432e-04 - val_loss: 5.5517e-04
# Epoch 94/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.6690e-04 - val_loss: 0.0017
# Epoch 95/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.3028e-04 - val_loss: 3.9006e-04
# Epoch 96/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.9228e-04 - val_loss: 0.0019
# Epoch 97/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5345e-04 - val_loss: 3.7778e-04
# Epoch 98/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5551e-04 - val_loss: 6.8249e-04
# Epoch 99/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.3296e-04 - val_loss: 0.0018
# Epoch 100/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.9544e-04 - val_loss: 0.0011
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
