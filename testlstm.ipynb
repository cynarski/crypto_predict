# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Ustawienia wyświetlania wykresów
# %matplotlib inline

# Pobranie danych od 01-01-2019 do 31-12-2022
df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')

# Użyjemy tylko kolumny 'Close' jako cechy
data = df[['Close']].values

# Skalowanie danych do zakresu (0,1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Definiowanie funkcji do tworzenia sekwencji danych
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        X.append(dataset[i-look_back:i, 0])
        Y.append(dataset[i, 0])
    return np.array(X), np.array(Y)

# Tworzenie sekwencji z look_back = 60 dni
look_back = 60
X, Y = create_dataset(scaled_data, look_back)

# Reshape danych wejściowych do formatu [próbki, timesteps, cechy]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Podział na zbiór treningowy i testowy (80% treningowy, 20% walidacyjny)
train_size = int(len(X) * 0.7)
X_train, X_val = X[:train_size], X[train_size:]
Y_train, Y_val = Y[:train_size], Y[train_size:]

# Budowa modelu LSTM
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.3))
model.add(LSTM(units=64))
model.add(Dropout(0.3))
model.add(Dense(25))
model.add(Dense(1))
model.summary()
model.compile(loss='mean_squared_error', optimizer='adam')

# Trenowanie modelu z walidacją
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_data=(X_val, Y_val), verbose=1)

# Predykcja na zbiorze walidacyjnym
predicted_val = model.predict(X_val)
predicted_val = scaler.inverse_transform(predicted_val)
Y_val_inverse = scaler.inverse_transform(Y_val.reshape(-1, 1))

# Pobranie dat dla zbioru walidacyjnego
validation_dates = df.index[look_back + train_size:]

# Wykres porównujący na zbiorze walidacyjnym
plt.figure(figsize=(14,5))
plt.plot(validation_dates, Y_val_inverse, color='black', label='Rzeczywiste ceny AAPL (walidacja)')
plt.plot(validation_dates, predicted_val, color='green', label='Przewidywane ceny AAPL (walidacja)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL na zbiorze walidacyjnym')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()

# Pobranie danych do 31-12-2022 dla predykcji na styczeń 2023
train_data = yf.download('AAPL', start='2019-01-01', end='2023-12-31')
train_close = train_data[['Close']].values

# Pobranie danych od 01-01-2023 do 31-01-2023 (bez patrzenia na nie)
test_data = yf.download('AAPL', start='2024-01-01', end='2024-05-31')
actual_prices = test_data[['Close']].values

# Łączenie danych w celu zachowania ciągłości sekwencji
total_dataset = np.concatenate((train_close, actual_prices), axis=0)

# Przygotowanie danych do predykcji
inputs = total_dataset[len(total_dataset) - len(actual_prices) - look_back:]
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(look_back, len(inputs)):
    X_test.append(inputs[i-look_back:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Predykcja cen na styczeń 2023
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)

# Rzeczywiste ceny zamknięcia dla stycznia 2023
real_prices = test_data['Close'].values

# Daty dla stycznia 2023
test_dates = test_data.index

# Wykres porównujący dla stycznia 2023
plt.figure(figsize=(14,5))
plt.plot(test_dates, real_prices, color='red', label='Rzeczywiste ceny AAPL (styczeń 2023)')
plt.plot(test_dates, predicted_prices, color='green', label='Przewidywane ceny AAPL (styczeń 2023)')
plt.title('Porównanie przewidywanych i rzeczywistych cen akcji AAPL w styczniu 2023')
plt.xlabel('Data')
plt.ylabel('Cena akcji')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Michał\Desktop\crypto\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 60, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 117,619 (459.45 KB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0126 - val_loss: 0.0011
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 8.6901e-04 - val_loss: 0.0065
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 8.4503e-04 - val_loss: 0.0028
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 8.7547e-04 - val_loss: 9.2377e-04
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 7.0630e-04 - val_loss: 0.0026
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 7.5465e-04 - val_loss: 0.0018
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.9466e-04 - val_loss: 8.5151e-04
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.9419e-04 - val_loss: 0.0023
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.4143e-04 - val_loss: 0.0023
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.6140e-04 - val_loss: 0.0018
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.8690e-04 - val_loss: 0.0011
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.9156e-04 - val_loss: 0.0013
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.9932e-04 - val_loss: 8.8981e-04
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.0677e-04 - val_loss: 0.0034
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.0435e-04 - val_loss: 7.8907e-04
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.2597e-04 - val_loss: 0.0020
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.1059e-04 - val_loss: 7.4004e-04
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.3436e-04 - val_loss: 0.0035
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.3317e-04 - val_loss: 0.0049
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.8769e-04 - val_loss: 0.0018
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.5170e-04 - val_loss: 6.7309e-04
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.3340e-04 - val_loss: 8.8106e-04
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.2214e-04 - val_loss: 7.8316e-04
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.4246e-04 - val_loss: 6.4102e-04
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.7540e-04 - val_loss: 5.8249e-04
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.6469e-04 - val_loss: 6.4420e-04
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.0151e-04 - val_loss: 7.4910e-04
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7486e-04 - val_loss: 9.5574e-04
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.4954e-04 - val_loss: 5.9731e-04
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.5399e-04 - val_loss: 8.3359e-04
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.4358e-04 - val_loss: 0.0016
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.4192e-04 - val_loss: 9.2590e-04
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.2249e-04 - val_loss: 9.9573e-04
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.6459e-04 - val_loss: 5.5509e-04
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.8263e-04 - val_loss: 0.0015
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.1519e-04 - val_loss: 5.1128e-04
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.1117e-04 - val_loss: 0.0025
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.4862e-04 - val_loss: 5.4554e-04
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.8644e-04 - val_loss: 7.3876e-04
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.2321e-04 - val_loss: 6.0866e-04
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.0477e-04 - val_loss: 5.6019e-04
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.4725e-04 - val_loss: 0.0018
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.3015e-04 - val_loss: 0.0020
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.7988e-04 - val_loss: 8.2175e-04
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.1285e-04 - val_loss: 0.0013
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.5839e-04 - val_loss: 0.0013
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.4361e-04 - val_loss: 0.0011
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3169e-04 - val_loss: 5.7478e-04
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.7132e-04 - val_loss: 0.0024
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.8985e-04 - val_loss: 0.0011
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.7979e-04 - val_loss: 0.0028
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.5549e-04 - val_loss: 0.0071
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.2442e-04 - val_loss: 4.8069e-04
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.8271e-04 - val_loss: 4.4292e-04
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.9046e-04 - val_loss: 7.1387e-04
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.1911e-04 - val_loss: 0.0033
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.1917e-04 - val_loss: 0.0012
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.0475e-04 - val_loss: 0.0023
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.3265e-04 - val_loss: 0.0023
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7561e-04 - val_loss: 0.0015
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.4470e-04 - val_loss: 4.8184e-04
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0569e-04 - val_loss: 0.0032
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.8058e-04 - val_loss: 7.9127e-04
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.9329e-04 - val_loss: 0.0043
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3499e-04 - val_loss: 0.0036
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.6245e-04 - val_loss: 6.3508e-04
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.9801e-04 - val_loss: 0.0012
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0364e-04 - val_loss: 8.2124e-04
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7706e-04 - val_loss: 4.3997e-04
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5179e-04 - val_loss: 0.0012
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.0114e-04 - val_loss: 5.2411e-04
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3459e-04 - val_loss: 4.1132e-04
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8027e-04 - val_loss: 5.5640e-04
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.6406e-04 - val_loss: 3.9215e-04
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5635e-04 - val_loss: 4.0586e-04
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.7106e-04 - val_loss: 3.7770e-04
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8381e-04 - val_loss: 0.0052
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.7021e-04 - val_loss: 4.1914e-04
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.1990e-04 - val_loss: 8.4748e-04
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.2382e-04 - val_loss: 0.0011
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0718e-04 - val_loss: 0.0016
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.4469e-04 - val_loss: 7.9903e-04
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.0301e-04 - val_loss: 0.0018
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.1588e-04 - val_loss: 0.0017
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.1186e-04 - val_loss: 0.0020
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.2027e-04 - val_loss: 7.3462e-04
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7211e-04 - val_loss: 0.0031
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.2654e-04 - val_loss: 3.8982e-04
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.5770e-04 - val_loss: 3.8900e-04
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.5759e-04 - val_loss: 0.0016
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3061e-04 - val_loss: 3.9044e-04
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.1328e-04 - val_loss: 9.9477e-04
# Epoch 93/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.3261e-04 - val_loss: 0.0026
# Epoch 94/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8504e-04 - val_loss: 9.9784e-04
# Epoch 95/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.2206e-04 - val_loss: 4.3282e-04
# Epoch 96/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.1992e-04 - val_loss: 3.6688e-04
# Epoch 97/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.9708e-04 - val_loss: 0.0021
# Epoch 98/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.6641e-04 - val_loss: 0.0013
# Epoch 99/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8595e-04 - val_loss: 9.1259e-04
# Epoch 100/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.0264e-04 - val_loss: 0.0013
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
