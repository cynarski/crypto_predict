# %%
from Arima import MyArima
from GRU import MyGRU
from LSTM import MyLSTM
from MonteCarlo import MyMonteCarlo
from Prophet import MyProphet
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm  import tqdm

# %%
df = yf.download('ETH-USD', start='2020-01-01', end='2021-12-31')
data = df[['Close']].values
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gru_model = MyGRU(epochs=25)
gru_model.create_model()
gru_model.fit(data)

lstm_model = MyLSTM(epochs=25)
lstm_model.create_model()
lstm_model.fit(data)
# Out:
# C:\Users\Michał\Desktop\crypto\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 60, 256)        │       198,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 60, 128)        │       148,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 386,035 (1.47 MB)
#  Trainable params: 386,035 (1.47 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 209ms/step - loss: 0.0396 - val_loss: 0.0709
# Epoch 2/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0096 - val_loss: 0.0335
# Epoch 3/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0041 - val_loss: 0.0161
# Epoch 4/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 5/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 6/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 7/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 8/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 8.9684e-04 - val_loss: 0.0018
# Epoch 9/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 10/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 11/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 6.5834e-04 - val_loss: 0.0024
# Epoch 12/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 7.5825e-04 - val_loss: 0.0018
# Epoch 13/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 14/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 9.3823e-04 - val_loss: 0.0018
# Epoch 15/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 9.9440e-04 - val_loss: 0.0022
# Epoch 16/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 17/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 18/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 7.9506e-04 - val_loss: 0.0015
# Epoch 19/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 20/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 8.4581e-04 - val_loss: 0.0014
# Epoch 21/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 7.2425e-04 - val_loss: 0.0024
# Epoch 22/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 6.0445e-04 - val_loss: 0.0014
# Epoch 23/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 8.7730e-04 - val_loss: 0.0026
# Epoch 24/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 7.4991e-04 - val_loss: 0.0045
# Epoch 25/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0011 - val_loss: 0.0018
# C:\Users\Michał\Desktop\crypto\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 60, 256)        │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 60, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 512,371 (1.95 MB)
#  Trainable params: 512,371 (1.95 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - loss: 0.0465 - val_loss: 0.0855
# Epoch 2/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0071 - val_loss: 0.0050
# Epoch 3/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 4/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0027 - val_loss: 0.0162
# Epoch 5/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 6/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0020 - val_loss: 0.0105
# Epoch 7/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0020 - val_loss: 0.0066
# Epoch 8/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0017 - val_loss: 0.0120
# Epoch 9/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0018 - val_loss: 0.0083
# Epoch 10/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0018 - val_loss: 0.0220
# Epoch 11/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 12/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0019 - val_loss: 0.0068
# Epoch 13/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0019 - val_loss: 0.0116
# Epoch 14/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0018 - val_loss: 0.0128
# Epoch 15/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.0019 - val_loss: 0.0076
# Epoch 16/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0019 - val_loss: 0.0081
# Epoch 17/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0012 - val_loss: 0.0106
# Epoch 18/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 19/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0011 - val_loss: 0.0123
# Epoch 20/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0014 - val_loss: 0.0177
# Epoch 21/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 22/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0016 - val_loss: 0.0088
# Epoch 23/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0013 - val_loss: 0.0059
# Epoch 24/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0019 - val_loss: 0.0325
# Epoch 25/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0025 - val_loss: 0.0071

# %%
test_data = yf.download('ETH-USD', start='2022-01-01', end='2022-01-31')
actual_prices = test_data[['Close']].values
length = len(actual_prices)

total_dataset = np.concatenate((data, actual_prices), axis=0)
# Prognozowanie
predicted_prices_gru = gru_model.predict(total_dataset, length)
predicted_prices_lstm = lstm_model.predict(total_dataset, length)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
plt.figure(figsize=(14,5))
plt.plot(test_data.index,actual_prices, color='red', label='Rzeczywiste ceny ETH (2022-01 do 2022-03)')
plt.plot(test_data.index,predicted_prices_gru, color='green', label='GRU')
plt.plot(test_data.index,predicted_prices_lstm, color='blue', label='LSTM')
plt.title('Porównanie przewidywanych i rzeczywistych cen ETH od 2022-01 do 2022-03')
plt.xlabel('Data')
plt.ylabel('Cena ETH')
plt.legend()
plt.show()

# %%
import yfinance as yf
import numpy as np
from Arima import MyArima
from LSTM import MyLSTM
from Prophet import MyProphet
from MonteCarlo import MyMonteCarlo
import matplotlib.pyplot as plt
from datetime import datetime

df = yf.download('ETH-USD', start='2014-01-01', end='2021-12-31')
data = df[['Close']].values
test_data = yf.download('ETH-USD', start='2022-01-01', end='2022-01-31')

start_date = datetime.strptime('2022-01-01', '%Y-%m-%d')
end_date = datetime.strptime('2022-12-31', '%Y-%m-%d')
periods = (end_date - start_date).days

prophet_model = MyProphet()
prophet_model.create_model()
prophet_model.fit(df)
predictions = prophet_model.predict(periods)
# print(predictions)

plt.plot(test_data.index,test_data['Close'])
plt.plot(test_data.index,predictions['yhat'])
plt.show()
# monte_carlo_model = MyMonteCarlo(iterations=1000000)
# monte_carlo_model.fit(data)
# predictions = arima_model.predict()
# filtered_data = predictions.loc[predictions['ds'] >= '2023-01-31']
# first_day = filtered_data['ds'].iloc[0]
# last_day = filtered_data['ds'].iloc[-1]
# print(first_day, last_day)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 18
#      15 end_date = datetime.strptime('2022-12-31', '%Y-%m-%d')
#      16 periods = (end_date - start_date).days
# ---> 18 prophet_model = MyProphet()
#      19 prophet_model.create_model()
#      20 prophet_model.fit(df)
#
# File ~\Desktop\crypto\models\Prophet.py:8, in MyProphet.__init__(self)
#       7 def __init__(self):
# ----> 8     self.model = Prophet(
#       9         changepoint_prior_scale=0.4,
#      10         growth='linear',
#      11         seasonality_prior_scale=0.3,
#      12         seasonality_mode='multiplicative',
#      13         weekly_seasonality=False,
#      14         daily_seasonality=False,
#      15     )
#
# File ~\Desktop\crypto\venv\lib\site-packages\prophet\forecaster.py:155, in Prophet.__init__(self, growth, changepoints, n_changepoints, changepoint_range, yearly_seasonality, weekly_seasonality, daily_seasonality, holidays, seasonality_mode, seasonality_prior_scale, holidays_prior_scale, changepoint_prior_scale, mcmc_samples, interval_width, uncertainty_samples, stan_backend, scaling, holidays_mode)
#     153 self.fit_kwargs = {}
#     154 self.validate_inputs()
# --> 155 self._load_stan_backend(stan_backend)
#
# File ~\Desktop\crypto\venv\lib\site-packages\prophet\forecaster.py:168, in Prophet._load_stan_backend(self, stan_backend)
#     165 else:
#     166     self.stan_backend = StanBackendEnum.get_backend_class(stan_backend)()
# --> 168 logger.debug("Loaded stan backend: %s", self.stan_backend.get_type())
#
# AttributeError: 'Prophet' object has no attribute 'stan_backend'

# %%
actual_prices
# Out:
# array([[3769.69702148],
#        [3829.56494141],
#        [3761.38037109],
#        [3794.05664062],
#        [3550.38696289],
#        [3418.40820312],
#        [3193.21044922],
#        [3091.97265625],
#        [3157.75146484],
#        [3083.09790039],
#        [3238.11157227],
#        [3372.25830078],
#        [3248.28857422],
#        [3310.00146484],
#        [3330.53076172],
#        [3350.921875  ],
#        [3212.30493164],
#        [3164.02514648],
#        [3095.82592773],
#        [3001.12011719],
#        [2557.93164062],
#        [2405.18115234],
#        [2535.0390625 ],
#        [2440.35229492],
#        [2455.93505859],
#        [2468.03027344],
#        [2423.0012207 ],
#        [2547.09204102],
#        [2597.0847168 ],
#        [2603.46655273],
#        [2688.27880859],
#        [2792.1171875 ],
#        [2682.85400391],
#        [2679.16259766],
#        [2983.58691406],
#        [3014.64819336],
#        [3057.47607422],
#        [3142.47070312],
#        [3122.60864258],
#        [3239.45703125],
#        [3077.48217773],
#        [2927.38354492],
#        [2917.36279297],
#        [2883.46337891],
#        [2933.47900391],
#        [3179.87719727],
#        [3127.83007812],
#        [2881.48193359],
#        [2785.72753906],
#        [2763.70117188],
#        [2628.6484375 ],
#        [2573.81616211],
#        [2639.29931641],
#        [2590.35961914],
#        [2598.06713867],
#        [2764.53564453],
#        [2781.11181641],
#        [2621.80175781],
#        [2919.20117188],
#        [2972.48510742],
#        [2950.1184082 ],
#        [2834.46899414],
#        [2617.15600586],
#        [2664.83105469],
#        [2555.03735352],
#        [2497.77124023],
#        [2576.74755859],
#        [2729.78344727],
#        [2608.04858398],
#        [2559.56298828],
#        [2574.75415039],
#        [2518.94458008],
#        [2590.69604492],
#        [2620.1496582 ],
#        [2772.05566406],
#        [2814.85449219],
#        [2945.34301758],
#        [2946.25708008],
#        [2860.45922852],
#        [2897.9765625 ],
#        [2973.13110352],
#        [3031.06713867],
#        [3108.06201172],
#        [3106.67138672],
#        [3143.17895508],
#        [3291.57763672],
#        [3336.63452148],
#        [3401.98779297],
#        [3385.15795898],
#        [3281.64282227]])

# %%
arima_model = MyArima(interval=60)
arima_model.fit(df)
# test_data = yf.download('ETH-USD', start='2022-01-01', end='2022-04-01')
forecast_dates = pd.date_range(start='2022-01-01', end='2022-01-31')
forecast_length = len(forecast_dates)
arima_predictions = arima_model.predict(forecast_length, forecast_dates)
# print(len(arima_predictions))
# print(len(predicted_prices_gru))
plt.figure(figsize=(14,5))
plt.plot(test_data.index,actual_prices, color='red', label='Rzeczywiste ceny ETH (2022-01 do 2022-03)')
# plt.plot(test_data.index,predicted_prices_gru, color='green', label='GRU')
# plt.plot(test_data.index,predicted_prices_lstm, color='blue', label='LSTM')
plt.plot(arima_predictions, color='blue', label='ARIMA')
# plt.plot(test_data.index,predictions['yhat'], label='Prophet', color='orange')
plt.title('Porównanie przewidywanych i rzeczywistych cen ETH od 2022-01 do 2022-03')
plt.xlabel('Data')
plt.ylabel('Cena ETH')
plt.legend()
plt.show()

# %%
actual_prices
# Out:
# array([[3769.69702148],
#        [3829.56494141],
#        [3761.38037109],
#        [3794.05664062],
#        [3550.38696289],
#        [3418.40820312],
#        [3193.21044922],
#        [3091.97265625],
#        [3157.75146484],
#        [3083.09790039],
#        [3238.11157227],
#        [3372.25830078],
#        [3248.28857422],
#        [3310.00146484],
#        [3330.53076172],
#        [3350.921875  ],
#        [3212.30493164],
#        [3164.02514648],
#        [3095.82592773],
#        [3001.12011719],
#        [2557.93164062],
#        [2405.18115234],
#        [2535.0390625 ],
#        [2440.35229492],
#        [2455.93505859],
#        [2468.03027344],
#        [2423.0012207 ],
#        [2547.09204102],
#        [2597.0847168 ],
#        [2603.46655273],
#        [2688.27880859],
#        [2792.1171875 ],
#        [2682.85400391],
#        [2679.16259766],
#        [2983.58691406],
#        [3014.64819336],
#        [3057.47607422],
#        [3142.47070312],
#        [3122.60864258],
#        [3239.45703125],
#        [3077.48217773],
#        [2927.38354492],
#        [2917.36279297],
#        [2883.46337891],
#        [2933.47900391],
#        [3179.87719727],
#        [3127.83007812],
#        [2881.48193359],
#        [2785.72753906],
#        [2763.70117188],
#        [2628.6484375 ],
#        [2573.81616211],
#        [2639.29931641],
#        [2590.35961914],
#        [2598.06713867],
#        [2764.53564453],
#        [2781.11181641],
#        [2621.80175781],
#        [2919.20117188],
#        [2972.48510742],
#        [2950.1184082 ],
#        [2834.46899414],
#        [2617.15600586],
#        [2664.83105469],
#        [2555.03735352],
#        [2497.77124023],
#        [2576.74755859],
#        [2729.78344727],
#        [2608.04858398],
#        [2559.56298828],
#        [2574.75415039],
#        [2518.94458008],
#        [2590.69604492],
#        [2620.1496582 ],
#        [2772.05566406],
#        [2814.85449219],
#        [2945.34301758],
#        [2946.25708008],
#        [2860.45922852],
#        [2897.9765625 ],
#        [2973.13110352],
#        [3031.06713867],
#        [3108.06201172],
#        [3106.67138672],
#        [3143.17895508],
#        [3291.57763672],
#        [3336.63452148],
#        [3401.98779297],
#        [3385.15795898],
#        [3281.64282227]])
